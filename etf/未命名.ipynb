# %%
def get_trade_day_bar(unit='W' , n=1 ,start_date=None,end_date=None,count=None):
    """
    unit : 频率 , "W"代表周 或者 "M"代表月
    n : 第几个交易日 , 每月第一个交易日: n=1 , 每月最后一个交易日 : n= -1 ,每月倒数第三个交易日 : n= -3 , 如果不足abs(n)个交易日,则返回符合条件的最近的一个交易日 
    start_date : 开始时间
    end_date : 结束时间
    count : 返回数据条数 , 指定start_date及count时返回start_date向后count条数据 , 指定end_date及count时返回end_date向前count条数据

    返回的数据会在 get_all_trade_days 以内
    返回 : 一个dataframe ,具体列含义见源码, date列就是需要获取的交易日了(datetime格式) 
    """
    # import pandas as pd
    # import QUANTAXIS as QA 
    
    # trade_day=[i for i in QA.trade_date_sse if i >='2015-01-01' and i <'2021-03-27']
    df = pd.DataFrame(pd.to_datetime(QA.trade_date_sse),columns=['date'])
    week_stamp = 24*60*60*7
    day_stamp = 24*60*60
#     print(df)
    df['timestamp'] = df.date.apply(lambda x: x.timestamp() - day_stamp*3  )  #基于1970-01-01偏移三天
    df['mkweek'] = df.timestamp // week_stamp     # 1970-01-01 至今的第几周, 直接取每年的第几周再换年时会有问题
#     df['weekday'] = (df.timestamp %  week_stamp)/day_stamp   #周几
#     df['monthday'] = df.date.apply(lambda x : x.day)  #日
    df['month'] = df.date.apply(lambda x : x.month)   #月
    df['year'] = df.date.apply(lambda x : x.year)     #年
#     print(df)
    if unit == "W":
        group_list = ['mkweek']
    elif unit =="M":
        group_list = ["year","month"]
    else :
        raise ValueError ('只支持M参数为 "M"或"W" ')

    if not isinstance(n , int):
        raise ValueError ('n 参数应该是一个int')
    elif n >0 :
        res =  df.groupby(group_list,as_index=False).head(n).groupby(group_list,as_index=False).last()
    elif n< 0:
        res =  df.groupby(group_list,as_index=False).tail(-n).groupby(group_list,as_index=False).first()    
    else :
        raise ValueError ('n 参数错误 : n={}'.format(n))


    if start_date and end_date and count:
        raise ValueError ('start_date ,end_date ,count 必须三选二')

    elif start_date and count :
        return res[res.date>=start_date].head(count)
    elif end_date and count :
        return res[res.date<=end_date].tail(count)
    elif start_date and end_date:
        return res[(res.date<=end_date)&(res.date>=start_date)]
    elif not  start_date and not end_date and not  count:
        return res
    else:
        raise ValueError ('start_date ,end_date ,count 必须三选二')

# %%
def change_vol_positions(acc,R):
    balance=acc.balance
    available=acc.available
    # pos=acc.get_position(code)
    change=[]
    for i in R.keys():
        pos=acc.get_position(i)
        pos_market_value=pos.volume_long*pos.last_price#持仓市值
        end_ratio=int(balance*R.get(i)/pos.last_price//100*100)#调仓目标
        if end_ratio-pos.volume_long>0:
            print('{}：调仓买入{}股'.format(i,end_ratio-pos.volume_long))
        elif end_ratio-pos.volume_long<0:
            print('{}：调仓卖出{}股'.format(i,abs(end_ratio-pos.volume_long)))
        change.append({'code':i,'price':pos.last_price,'原持仓数量':pos.volume_long,'原持仓市值':pos_market_value,'调仓目标':end_ratio,'调仓数量':end_ratio-pos.volume_long})
    print(change)
    return change

# %%
import QUANTAXIS as QA
import pandas as pd
import datetime
from QIFIAccount import QIFI_Account,ORDER_DIRECTION

codes=['510300','518880','511260']
start='2017-09-01'
end='2021-04-26'
trade_day=[i for i in QA.trade_date_sse if i >=start and i <=end]
change_day=get_trade_day_bar(unit='M',n=-1,start_date='2015-01-01',end_date='2021-04-27').date.astype('str').tolist()
data=QA.QA_fetch_index_day_adv(code=codes,start=start,end=end)
R={'510300':0.3,'518880':0.3,'511260':0.3}
acc=QIFI_Account('FOF','FOF',model='BACKTEST',trade_host='172.19.0.2',nodatabase=False)
acc.initial()
for code in R.keys():
    acc.get_position(code) 
for day in trade_day:
    hq_data=data.data.loc[(day,slice(None)),:]
#     print(hq_data)
    for i in range(len(hq_data)):
        bar=hq_data.iloc[i]
        price=bar.close
        acc.on_price_change(code=bar.name[1],price=bar.close,datetime=str(bar.name[0])[:10]+' '+'15:00:00')
    if day in change_day: 
        change=change_vol_positions(acc,R)
        change_df=pd.DataFrame(change).sort_values(by='调仓数量',ascending=False)
        print('账户市值：',acc.balance)
        print('账户可用资金：',acc.available)
        for i in range(len(change_df)):
            ord=change_df.iloc[i]
            if ord['调仓数量']>0:
                od=acc.send_order(
                    code=ord['code'],
                    amount=ord['调仓数量'] ,
                    price=ord['price'],
                    towards=ORDER_DIRECTION.BUY_OPEN)
                acc.make_deal(od)
            elif ord['调仓数量']<0:
                od=acc.send_order(
                    code=ord['code'],
                    amount=abs(ord['调仓数量']) ,
                    price=ord['price'],
                    towards=ORDER_DIRECTION.SELL_CLOSE)
                acc.make_deal(od)
    acc.settle()
# Out:
# Create new Account
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入76800股
# 518880：调仓买入109400股
# 511260：调仓买入2900股
# [{'code': '510300', 'price': 3.902, '原持仓数量': 0, '原持仓市值': 0.0, '调仓目标': 76800, '调仓数量': 76800}, {'code': '518880', 'price': 2.742, '原持仓数量': 0, '原持仓市值': 0.0, '调仓目标': 109400, '调仓数量': 109400}, {'code': '511260', 'price': 100.01, '原持仓数量': 0, '原持仓市值': 0.0, '调仓目标': 2900, '调仓数量': 2900}]
# 账户市值： 1000000.0
# 账户可用资金： 1000000
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 79be49a5-1d34-459a-a539-4a33d5e972d6
# 全部成交 79be49a5-1d34-459a-a539-4a33d5e972d6
# update trade
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 f48948bd-8ae3-462b-83e9-c78b5d122399
# 全部成交 f48948bd-8ae3-462b-83e9-c78b5d122399
# update trade
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 1992d46a-b951-48d2-a241-d95e74cadbfd
# 全部成交 1992d46a-b951-48d2-a241-d95e74cadbfd
# update trade
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出2400股
# 518880：调仓买入1800股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 4.062, '原持仓数量': 76800, '原持仓市值': 311961.60000000003, '调仓目标': 74400, '调仓数量': -2400}, {'code': '518880', 'price': 2.718, '原持仓数量': 109400, '原持仓市值': 297349.2, '调仓目标': 111200, '调仓数量': 1800}, {'code': '511260', 'price': 99.386, '原持仓数量': 2900, '原持仓市值': 288219.39999999997, '调仓目标': 3000, '调仓数量': 100}]
# 账户市值： 1007852.8
# 账户可用资金： 110322.59999999992
# {'volume_long': 109400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 109400, 'volume_short': 0}
# order check success
# 下单成功 3d88097f-e665-4f1a-b98a-c866efae9340
# 全部成交 3d88097f-e665-4f1a-b98a-c866efae9340
# update trade
# {'volume_long': 2900, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2900, 'volume_short': 0}
# order check success
# 下单成功 a96946d8-2a9c-4022-85b1-b7dc423c233b
# 全部成交 a96946d8-2a9c-4022-85b1-b7dc423c233b
# update trade
# {'volume_long': 76800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 76800, 'volume_short': 0}
# order check success
# 下单成功 879d1318-bf4f-4ab4-835b-280b08b7e3e4
# 全部成交 879d1318-bf4f-4ab4-835b-280b08b7e3e4
# update trade
# {'volume_long': 74400, 'volume_short': 0, 'volume_long_frozen': 2400, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出200股
# 518880：调仓卖出600股
# [{'code': '510300', 'price': 4.054, '原持仓数量': 74400, '原持仓市值': 301617.60000000003, '调仓目标': 74200, '调仓数量': -200}, {'code': '518880', 'price': 2.72, '原持仓数量': 111200, '原持仓市值': 302464.0, '调仓目标': 110600, '调仓数量': -600}, {'code': '511260', 'price': 97.822, '原持仓数量': 3000, '原持仓市值': 293466.0, '调仓目标': 3000, '调仓数量': 0}]
# 账户市值： 1003090.0903225807
# 账户可用资金： 105240.39999999992
# {'volume_long': 74400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 74400, 'volume_short': 0}
# order check success
# 下单成功 0f70f609-d16a-4bfa-a9d1-638fad1f9e93
# 全部成交 0f70f609-d16a-4bfa-a9d1-638fad1f9e93
# update trade
# {'volume_long': 74200, 'volume_short': 0, 'volume_long_frozen': 200, 'volume_short_frozen': 0}
# {'volume_long': 111200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 111200, 'volume_short': 0}
# order check success
# 下单成功 513cdfeb-aba5-438f-91b4-8199de984511
# 全部成交 513cdfeb-aba5-438f-91b4-8199de984511
# update trade
# {'volume_long': 110600, 'volume_short': 0, 'volume_long_frozen': 600, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出300股
# 518880：调仓买入600股
# [{'code': '510300', 'price': 4.076, '原持仓数量': 74200, '原持仓市值': 302439.19999999995, '调仓目标': 73900, '调仓数量': -300}, {'code': '518880', 'price': 2.708, '原持仓数量': 110600, '原持仓市值': 299504.80000000005, '调仓目标': 111200, '调仓数量': 600}, {'code': '511260', 'price': 98.116, '原持仓数量': 3000, '原持仓市值': 294348.0, '调仓目标': 3000, '调仓数量': 0}]
# 账户市值： 1004287.5034380963
# 账户可用资金： 107683.19999999992
# {'volume_long': 110600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 110600, 'volume_short': 0}
# order check success
# 下单成功 621b80c0-7afc-4ebe-a96c-024e0a1f4a3b
# 全部成交 621b80c0-7afc-4ebe-a96c-024e0a1f4a3b
# update trade
# {'volume_long': 74200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 74200, 'volume_short': 0}
# order check success
# 下单成功 bc063e60-2022-4cc9-9207-3f4c104973a1
# 全部成交 bc063e60-2022-4cc9-9207-3f4c104973a1
# update trade
# {'volume_long': 73900, 'volume_short': 0, 'volume_long_frozen': 300, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出2200股
# 518880：调仓买入800股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 4.271, '原持仓数量': 73900, '原持仓市值': 315626.89999999997, '调仓目标': 71700, '调仓数量': -2200}, {'code': '518880', 'price': 2.735, '原持仓数量': 111200, '原持仓市值': 304132.0, '调仓目标': 112000, '调仓数量': 800}, {'code': '511260', 'price': 98.053, '原持仓数量': 3000, '原持仓市值': 294159.0, '调仓目标': 3100, '调仓数量': 100}]
# 账户市值： 1021514.9239540624
# 账户可用资金： 107281.19999999992
# {'volume_long': 111200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 111200, 'volume_short': 0}
# order check success
# 下单成功 1fd5f685-d0a3-4956-a475-543407db314f
# 全部成交 1fd5f685-d0a3-4956-a475-543407db314f
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3000, 'volume_short': 0}
# order check success
# 下单成功 030305c4-9473-4d0c-bc24-63d49a4f20e4
# 全部成交 030305c4-9473-4d0c-bc24-63d49a4f20e4
# update trade
# {'volume_long': 73900, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 73900, 'volume_short': 0}
# order check success
# 下单成功 f540571c-86eb-4431-b526-e210e886759e
# 全部成交 f540571c-86eb-4431-b526-e210e886759e
# update trade
# {'volume_long': 71700, 'volume_short': 0, 'volume_long_frozen': 2200, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入3100股
# 518880：调仓卖出200股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 4.02, '原持仓数量': 71700, '原持仓市值': 288233.99999999994, '调仓目标': 74800, '调仓数量': 3100}, {'code': '518880', 'price': 2.692, '原持仓数量': 112000, '原持仓市值': 301504.0, '调仓目标': 111800, '调仓数量': -200}, {'code': '511260', 'price': 99.467, '原持仓数量': 3100, '原持仓市值': 308347.7, '调仓目标': 3000, '调仓数量': -100}]
# 账户市值： 1003339.6058204151
# 账户可用资金： 104684.09999999992
# {'volume_long': 71700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 71700, 'volume_short': 0}
# order check success
# 下单成功 1b5c14a1-e248-4c33-a23c-7e8fa0a836f1
# 全部成交 1b5c14a1-e248-4c33-a23c-7e8fa0a836f1
# update trade
# {'volume_long': 3100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3100, 'volume_short': 0}
# order check success
# 下单成功 0312a957-8c52-4672-b1ab-537f98165e83
# 全部成交 0312a957-8c52-4672-b1ab-537f98165e83
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 112000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 112000, 'volume_short': 0}
# order check success
# 下单成功 c0300508-3ca4-41c1-b9b6-60f6d9cc688e
# 全部成交 c0300508-3ca4-41c1-b9b6-60f6d9cc688e
# update trade
# {'volume_long': 111800, 'volume_short': 0, 'volume_long_frozen': 200, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入1700股
# 518880：调仓卖出1000股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 3.896, '原持仓数量': 74800, '原持仓市值': 291420.8, '调仓目标': 76500, '调仓数量': 1700}, {'code': '518880', 'price': 2.692, '原持仓数量': 111800, '原持仓市值': 300965.60000000003, '调仓目标': 110800, '调仓数量': -1000}, {'code': '511260', 'price': 99.565, '原持仓数量': 3000, '原持仓市值': 298695.0, '调仓目标': 2900, '调仓数量': -100}]
# 账户市值： 994692.4598134626
# 账户可用资金： 102707.19999999991
# {'volume_long': 74800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 74800, 'volume_short': 0}
# order check success
# 下单成功 9c621504-259b-47a3-aefc-39477d29e6d2
# 全部成交 9c621504-259b-47a3-aefc-39477d29e6d2
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3000, 'volume_short': 0}
# order check success
# 下单成功 07a39990-558f-4de8-bb8b-80d7f65ace6b
# 全部成交 07a39990-558f-4de8-bb8b-80d7f65ace6b
# update trade
# {'volume_long': 2900, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 111800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 111800, 'volume_short': 0}
# order check success
# 下单成功 57a3b6c7-8efc-4752-9e36-50e91c8970d3
# 全部成交 57a3b6c7-8efc-4752-9e36-50e91c8970d3
# update trade
# {'volume_long': 110800, 'volume_short': 0, 'volume_long_frozen': 1000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入2600股
# 518880：调仓卖出500股
# [{'code': '510300', 'price': 3.754, '原持仓数量': 76500, '原持仓市值': 287181.0, '调仓目标': 79100, '调仓数量': 2600}, {'code': '518880', 'price': 2.692, '原持仓数量': 110800, '原持仓市值': 298273.60000000003, '调仓目标': 110300, '调仓数量': -500}, {'code': '511260', 'price': 101.6, '原持仓数量': 2900, '原持仓市值': 294640.0, '调仓目标': 2900, '调仓数量': 0}]
# 账户市值： 990088.7014397068
# 账户可用资金： 108732.49999999991
# {'volume_long': 76500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 76500, 'volume_short': 0}
# order check success
# 下单成功 50acb241-09ca-442a-983e-a279f9ffd2b9
# 全部成交 50acb241-09ca-442a-983e-a279f9ffd2b9
# update trade
# {'volume_long': 110800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 110800, 'volume_short': 0}
# order check success
# 下单成功 de96e443-333a-4294-9dd0-76ea8ac66c4d
# 全部成交 de96e443-333a-4294-9dd0-76ea8ac66c4d
# update trade
# {'volume_long': 110300, 'volume_short': 0, 'volume_long_frozen': 500, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出700股
# 518880：调仓买入700股
# [{'code': '510300', 'price': 3.803, '原持仓数量': 79100, '原持仓市值': 300817.3, '调仓目标': 78400, '调仓数量': -700}, {'code': '518880', 'price': 2.686, '原持仓数量': 110300, '原持仓市值': 296265.8, '调仓目标': 111000, '调仓数量': 700}, {'code': '511260', 'price': 101.791, '原持仓数量': 2900, '原持仓市值': 295193.89999999997, '调仓目标': 2900, '调仓数量': 0}]
# 账户市值： 993862.7583340912
# 账户可用资金： 100318.09999999992
# {'volume_long': 110300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 110300, 'volume_short': 0}
# order check success
# 下单成功 18dfcc67-1ab1-466f-9f1c-137b4da381d4
# 全部成交 18dfcc67-1ab1-466f-9f1c-137b4da381d4
# update trade
# {'volume_long': 79100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 79100, 'volume_short': 0}
# order check success
# 下单成功 08221125-3dc9-49ff-b3b2-2f105640fadc
# 全部成交 08221125-3dc9-49ff-b3b2-2f105640fadc
# update trade
# {'volume_long': 78400, 'volume_short': 0, 'volume_long_frozen': 700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入3900股
# 518880：调仓卖出1500股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 3.537, '原持仓数量': 78400, '原持仓市值': 277300.8, '调仓目标': 82300, '调仓数量': 3900}, {'code': '518880', 'price': 2.661, '原持仓数量': 111000, '原持仓市值': 295371.0, '调仓目标': 109500, '调仓数量': -1500}, {'code': '511260', 'price': 102.2, '原持仓数量': 2900, '原持仓市值': 296380.0, '调仓目标': 2800, '调仓数量': -100}]
# 账户市值： 971438.8356523376
# 账户可用资金： 101099.99999999993
# {'volume_long': 78400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 78400, 'volume_short': 0}
# order check success
# 下单成功 243f41e5-05f7-46d9-bd58-8647f10b12b4
# 全部成交 243f41e5-05f7-46d9-bd58-8647f10b12b4
# update trade
# {'volume_long': 2900, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2900, 'volume_short': 0}
# order check success
# 下单成功 9ad7600d-9cf2-4833-8fcb-01cc44b7cdbe
# 全部成交 9ad7600d-9cf2-4833-8fcb-01cc44b7cdbe
# update trade
# {'volume_long': 2800, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 111000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 111000, 'volume_short': 0}
# order check success
# 下单成功 961dc565-f5e6-4947-8216-65304bc173fa
# 全部成交 961dc565-f5e6-4947-8216-65304bc173fa
# update trade
# {'volume_long': 109500, 'volume_short': 0, 'volume_long_frozen': 1500, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出300股
# 518880：调仓买入200股
# [{'code': '510300', 'price': 3.575, '原持仓数量': 82300, '原持仓市值': 294222.5, '调仓目标': 82000, '调仓数量': -300}, {'code': '518880', 'price': 2.673, '原持仓数量': 109500, '原持仓市值': 292693.5, '调仓目标': 109700, '调仓数量': 200}, {'code': '511260', 'price': 102.699, '原持仓数量': 2800, '原持仓市值': 287557.2, '调仓目标': 2800, '调仓数量': 0}]
# 账户市值： 977666.2912897398
# 账户可用资金： 101517.19999999992
# {'volume_long': 109500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 109500, 'volume_short': 0}
# order check success
# 下单成功 b4d32dfe-95d3-4372-8fef-f721976cbde9
# 全部成交 b4d32dfe-95d3-4372-8fef-f721976cbde9
# update trade
# {'volume_long': 82300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 82300, 'volume_short': 0}
# order check success
# 下单成功 0984a631-3db9-462d-b996-5aaa74833cf6
# 全部成交 0984a631-3db9-462d-b996-5aaa74833cf6
# update trade
# {'volume_long': 82000, 'volume_short': 0, 'volume_long_frozen': 300, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入2800股
# 518880：调仓卖出1000股
# [{'code': '510300', 'price': 3.39, '原持仓数量': 82000, '原持仓市值': 277980.0, '调仓目标': 84800, '调仓数量': 2800}, {'code': '518880', 'price': 2.646, '原持仓数量': 109700, '原持仓市值': 290266.2, '调仓目标': 108700, '调仓数量': -1000}, {'code': '511260', 'price': 102.577, '原持仓数量': 2800, '原持仓市值': 287215.6, '调仓目标': 2800, '调仓数量': 0}]
# 账户市值： 959194.931703002
# 账户可用资金： 102055.09999999992
# {'volume_long': 82000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 82000, 'volume_short': 0}
# order check success
# 下单成功 675c7cb5-da5c-49ac-bb93-799288f13807
# 全部成交 675c7cb5-da5c-49ac-bb93-799288f13807
# update trade
# {'volume_long': 109700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 109700, 'volume_short': 0}
# order check success
# 下单成功 641df54e-105f-447a-83e8-faba88d1ac85
# 全部成交 641df54e-105f-447a-83e8-faba88d1ac85
# update trade
# {'volume_long': 108700, 'volume_short': 0, 'volume_long_frozen': 1000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出2200股
# 518880：调仓买入1800股
# [{'code': '510300', 'price': 3.508, '原持仓数量': 84800, '原持仓市值': 297478.4, '调仓目标': 82600, '调仓数量': -2200}, {'code': '518880', 'price': 2.623, '原持仓数量': 108700, '原持仓市值': 285120.10000000003, '调仓目标': 110500, '调仓数量': 1800}, {'code': '511260', 'price': 102.373, '原持仓数量': 2800, '原持仓市值': 286644.4, '调仓目标': 2800, '调仓数量': 0}]
# 账户市值： 966154.3605559288
# 账户可用资金： 95209.09999999992
# {'volume_long': 108700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 108700, 'volume_short': 0}
# order check success
# 下单成功 12968615-a5b6-4aaa-b4ca-00b954511ef6
# 全部成交 12968615-a5b6-4aaa-b4ca-00b954511ef6
# update trade
# {'volume_long': 84800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 84800, 'volume_short': 0}
# order check success
# 下单成功 c15045d2-f9cf-4902-a229-1960526d9ec9
# 全部成交 c15045d2-f9cf-4902-a229-1960526d9ec9
# update trade
# {'volume_long': 82600, 'volume_short': 0, 'volume_long_frozen': 2200, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入6800股
# 518880：调仓卖出5300股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 3.205, '原持仓数量': 82600, '原持仓市值': 264733.0, '调仓目标': 89400, '调仓数量': 6800}, {'code': '518880', 'price': 2.724, '原持仓数量': 110500, '原持仓市值': 301002.0, '调仓目标': 105200, '调仓数量': -5300}, {'code': '511260', 'price': 103.402, '原持仓数量': 2800, '原持仓市值': 289525.6, '调仓目标': 2700, '调仓数量': -100}]
# 账户市值： 955379.398336796
# 账户可用资金： 98205.29999999993
# {'volume_long': 82600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 82600, 'volume_short': 0}
# order check success
# 下单成功 2d6842cb-ab74-4c89-bbfb-d05df0b24571
# 全部成交 2d6842cb-ab74-4c89-bbfb-d05df0b24571
# update trade
# {'volume_long': 2800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2800, 'volume_short': 0}
# order check success
# 下单成功 021bc8a0-2d71-4e3f-83a2-6d75be074545
# 全部成交 021bc8a0-2d71-4e3f-83a2-6d75be074545
# update trade
# {'volume_long': 2700, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 110500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 110500, 'volume_short': 0}
# order check success
# 下单成功 8c59761d-c6f8-4345-9a78-7145a56bb227
# 全部成交 8c59761d-c6f8-4345-9a78-7145a56bb227
# update trade
# {'volume_long': 105200, 'volume_short': 0, 'volume_long_frozen': 5300, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出100股
# 518880：调仓买入500股
# [{'code': '510300', 'price': 3.235, '原持仓数量': 89400, '原持仓市值': 289209.0, '调仓目标': 89300, '调仓数量': -100}, {'code': '518880', 'price': 2.732, '原持仓数量': 105200, '原持仓市值': 287406.4, '调仓目标': 105700, '调仓数量': 500}, {'code': '511260', 'price': 104.587, '原持仓数量': 2700, '原持仓市值': 282384.9, '调仓目标': 2700, '调仓数量': 0}]
# 账户市值： 963160.8589524995
# 账户可用资金： 101188.69999999992
# {'volume_long': 105200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 105200, 'volume_short': 0}
# order check success
# 下单成功 1f6e6d5f-1055-497a-9089-a796f3484309
# 全部成交 1f6e6d5f-1055-497a-9089-a796f3484309
# update trade
# {'volume_long': 89400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 89400, 'volume_short': 0}
# order check success
# 下单成功 821df0c3-2806-4656-ae0f-da4a772d50fb
# 全部成交 821df0c3-2806-4656-ae0f-da4a772d50fb
# update trade
# {'volume_long': 89300, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入5000股
# 518880：调仓卖出3700股
# [{'code': '510300', 'price': 3.059, '原持仓数量': 89300, '原持仓市值': 273168.7, '调仓目标': 94300, '调仓数量': 5000}, {'code': '518880', 'price': 2.826, '原持仓数量': 105700, '原持仓市值': 298708.2, '调仓目标': 102000, '调仓数量': -3700}, {'code': '511260', 'price': 106.134, '原持仓数量': 2700, '原持仓市值': 286561.8, '调仓目标': 2700, '调仓数量': 0}]
# 账户市值： 961556.2978352068
# 账户可用资金： 100146.19999999992
# {'volume_long': 89300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 89300, 'volume_short': 0}
# order check success
# 下单成功 527c7c79-85c0-49d4-ac6a-83241d393ce2
# 全部成交 527c7c79-85c0-49d4-ac6a-83241d393ce2
# update trade
# {'volume_long': 105700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 105700, 'volume_short': 0}
# order check success
# 下单成功 c3ad1dc9-8489-4c75-8cdc-857703ee0ccb
# 全部成交 c3ad1dc9-8489-4c75-8cdc-857703ee0ccb
# update trade
# {'volume_long': 102000, 'volume_short': 0, 'volume_long_frozen': 3700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出2800股
# 518880：调仓买入1300股
# [{'code': '510300', 'price': 3.202, '原持仓数量': 94300, '原持仓市值': 301948.6, '调仓目标': 91500, '调仓数量': -2800}, {'code': '518880', 'price': 2.837, '原持仓数量': 102000, '原持仓市值': 289374.0, '调仓目标': 103300, '调仓数量': 1300}, {'code': '511260', 'price': 106.351, '原持仓数量': 2700, '原持仓市值': 287147.7, '调仓目标': 2700, '调仓数量': 0}]
# 账户市值： 977086.021882739
# 账户可用资金： 95307.39999999992
# {'volume_long': 102000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 102000, 'volume_short': 0}
# order check success
# 下单成功 d9b2e4d4-c133-40f0-ab1c-cd458997f2ab
# 全部成交 d9b2e4d4-c133-40f0-ab1c-cd458997f2ab
# update trade
# {'volume_long': 94300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 94300, 'volume_short': 0}
# order check success
# 下单成功 2c8beb0a-d0ff-4225-a3b5-d98de3f6f095
# 全部成交 2c8beb0a-d0ff-4225-a3b5-d98de3f6f095
# update trade
# {'volume_long': 91500, 'volume_short': 0, 'volume_long_frozen': 2800, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出8200股
# 518880：调仓买入4500股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 3.663, '原持仓数量': 91500, '原持仓市值': 335164.5, '调仓目标': 83300, '调仓数量': -8200}, {'code': '518880', 'price': 2.833, '原持仓数量': 103300, '原持仓市值': 292648.9, '调仓目标': 107800, '调仓数量': 4500}, {'code': '511260', 'price': 106.01, '原持仓数量': 2700, '原持仓市值': 286227.0, '调仓目标': 2800, '调仓数量': 100}]
# 账户市值： 1018233.0098990401
# 账户可用资金： 100584.89999999992
# {'volume_long': 103300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 103300, 'volume_short': 0}
# order check success
# 下单成功 0690c3ec-1d40-47fa-b5a0-66ab80f50311
# 全部成交 0690c3ec-1d40-47fa-b5a0-66ab80f50311
# update trade
# {'volume_long': 2700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2700, 'volume_short': 0}
# order check success
# 下单成功 cb3d9e64-f262-4308-9042-8f0056d5cbcd
# 全部成交 cb3d9e64-f262-4308-9042-8f0056d5cbcd
# update trade
# {'volume_long': 91500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 91500, 'volume_short': 0}
# order check success
# 下单成功 7c72f34e-1751-49ea-b6fa-944ab3262445
# 全部成交 7c72f34e-1751-49ea-b6fa-944ab3262445
# update trade
# {'volume_long': 83300, 'volume_short': 0, 'volume_long_frozen': 8200, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出3000股
# 518880：调仓买入3600股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 3.869, '原持仓数量': 83300, '原持仓市值': 322287.7, '调仓目标': 80300, '调仓数量': -3000}, {'code': '518880', 'price': 2.788, '原持仓数量': 107800, '原持仓市值': 300546.39999999997, '调仓目标': 111400, '调仓数量': 3600}, {'code': '511260', 'price': 106.88, '原持仓数量': 2800, '原持仓市值': 299264.0, '调仓目标': 2900, '调仓数量': 100}]
# 账户市值： 1035919.3760900004
# 账户可用资金： 107271.99999999991
# {'volume_long': 107800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 107800, 'volume_short': 0}
# order check success
# 下单成功 1ab75f95-4cec-4fd1-b060-7f3a9470ccf4
# 全部成交 1ab75f95-4cec-4fd1-b060-7f3a9470ccf4
# update trade
# {'volume_long': 2800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2800, 'volume_short': 0}
# order check success
# 下单成功 aba4754b-14d0-4b1e-8cbc-d5c19f96fc99
# 全部成交 aba4754b-14d0-4b1e-8cbc-d5c19f96fc99
# update trade
# {'volume_long': 83300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 83300, 'volume_short': 0}
# order check success
# 下单成功 361c28a2-7a00-46dd-8343-78346bf83f0c
# 全部成交 361c28a2-7a00-46dd-8343-78346bf83f0c
# update trade
# {'volume_long': 80300, 'volume_short': 0, 'volume_long_frozen': 3000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1000股
# 518880：调仓卖出100股
# [{'code': '510300', 'price': 3.896, '原持仓数量': 80300, '原持仓市值': 312848.8, '调仓目标': 79300, '调仓数量': -1000}, {'code': '518880', 'price': 2.777, '原持仓数量': 111400, '原持仓市值': 309357.8, '调仓目标': 111300, '调仓数量': -100}, {'code': '511260', 'price': 104.796, '原持仓数量': 2900, '原持仓市值': 303908.4, '调仓目标': 2900, '调仓数量': 0}]
# 账户市值： 1031091.1321322776
# 账户可用资金： 98154.19999999991
# {'volume_long': 111400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 111400, 'volume_short': 0}
# order check success
# 下单成功 58b81e6d-239b-452b-8078-1d4800e3f296
# 全部成交 58b81e6d-239b-452b-8078-1d4800e3f296
# update trade
# {'volume_long': 111300, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 80300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 80300, 'volume_short': 0}
# order check success
# 下单成功 33489185-fd75-4746-9241-67b9b21e9b07
# 全部成交 33489185-fd75-4746-9241-67b9b21e9b07
# update trade
# {'volume_long': 79300, 'volume_short': 0, 'volume_long_frozen': 1000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入5300股
# 518880：调仓卖出4500股
# [{'code': '510300', 'price': 3.632, '原持仓数量': 79300, '原持仓市值': 288017.60000000003, '调仓目标': 84600, '调仓数量': 5300}, {'code': '518880', 'price': 2.878, '原持仓数量': 111300, '原持仓市值': 320321.4, '调仓目标': 106800, '调仓数量': -4500}, {'code': '511260', 'price': 105.917, '原持仓数量': 2900, '原持仓市值': 307159.3, '调仓目标': 2900, '调仓数量': 0}]
# 账户市值： 1024640.6412094142
# 账户可用资金： 102327.8999999999
# {'volume_long': 79300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 79300, 'volume_short': 0}
# order check success
# 下单成功 40a92cff-0cec-463e-b1ef-89ac025e090c
# 全部成交 40a92cff-0cec-463e-b1ef-89ac025e090c
# update trade
# {'volume_long': 111300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 111300, 'volume_short': 0}
# order check success
# 下单成功 054b8cd7-5580-4364-8f83-bc03f48705e7
# 全部成交 054b8cd7-5580-4364-8f83-bc03f48705e7
# update trade
# {'volume_long': 106800, 'volume_short': 0, 'volume_long_frozen': 4500, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1400股
# 518880：调仓卖出3600股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 3.859, '原持仓数量': 84600, '原持仓市值': 326471.4, '调仓目标': 83200, '调仓数量': -1400}, {'code': '518880', 'price': 3.109, '原持仓数量': 106800, '原持仓市值': 332041.2, '调仓目标': 103200, '调仓数量': -3600}, {'code': '511260', 'price': 106.436, '原持仓数量': 2900, '原持仓市值': 308664.4, '调仓目标': 3000, '调仓数量': 100}]
# 账户市值： 1070491.4972304222
# 账户可用资金： 96029.2999999999
# {'volume_long': 2900, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2900, 'volume_short': 0}
# order check success
# 下单成功 3b4c5d03-19bb-48a2-aec0-bac442d7a8ce
# 全部成交 3b4c5d03-19bb-48a2-aec0-bac442d7a8ce
# update trade
# {'volume_long': 84600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 84600, 'volume_short': 0}
# order check success
# 下单成功 3fe2af4b-a588-4d54-a3b6-3ef1b170a1ca
# 全部成交 3fe2af4b-a588-4d54-a3b6-3ef1b170a1ca
# update trade
# {'volume_long': 83200, 'volume_short': 0, 'volume_long_frozen': 1400, 'volume_short_frozen': 0}
# {'volume_long': 106800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 106800, 'volume_short': 0}
# order check success
# 下单成功 86455af3-03b2-46f2-b9e6-6afd4e0368e0
# 全部成交 86455af3-03b2-46f2-b9e6-6afd4e0368e0
# update trade
# {'volume_long': 103200, 'volume_short': 0, 'volume_long_frozen': 3600, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 518880：调仓卖出700股
# [{'code': '510300', 'price': 3.896, '原持仓数量': 83200, '原持仓市值': 324147.2, '调仓目标': 83200, '调仓数量': 0}, {'code': '518880', 'price': 3.164, '原持仓数量': 103200, '原持仓市值': 326524.8, '调仓目标': 102500, '调仓数量': -700}, {'code': '511260', 'price': 107.139, '原持仓数量': 3000, '原持仓市值': 321417.0, '调仓目标': 3000, '调仓数量': 0}]
# 账户市值： 1081658.4379570102
# 账户可用资金： 101980.6999999999
# {'volume_long': 103200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 103200, 'volume_short': 0}
# order check success
# 下单成功 d893eb71-1061-4e4f-aaa3-6c31a32c63bb
# 全部成交 d893eb71-1061-4e4f-aaa3-6c31a32c63bb
# update trade
# {'volume_long': 102500, 'volume_short': 0, 'volume_long_frozen': 700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入3500股
# 518880：调仓卖出7000股
# [{'code': '510300', 'price': 3.861, '原持仓数量': 83200, '原持仓市值': 321235.2, '调仓目标': 86700, '调仓数量': 3500}, {'code': '518880', 'price': 3.508, '原持仓数量': 102500, '原持仓市值': 359570.0, '调仓目标': 95500, '调仓数量': -7000}, {'code': '511260', 'price': 108.159, '原持仓数量': 3000, '原持仓市值': 324477.0, '调仓目标': 3000, '调仓数量': 0}]
# 账户市值： 1117066.3142488685
# 账户可用资金： 104195.4999999999
# {'volume_long': 83200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 83200, 'volume_short': 0}
# order check success
# 下单成功 e65cc9ce-04e4-456a-9380-6dfc045d427b
# 全部成交 e65cc9ce-04e4-456a-9380-6dfc045d427b
# update trade
# {'volume_long': 102500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 102500, 'volume_short': 0}
# order check success
# 下单成功 7d8005c0-7174-49a0-a772-9c6c57328358
# 全部成交 7d8005c0-7174-49a0-a772-9c6c57328358
# update trade
# {'volume_long': 95500, 'volume_short': 0, 'volume_long_frozen': 7000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1000股
# 518880：调仓买入2200股
# [{'code': '510300', 'price': 3.869, '原持仓数量': 86700, '原持仓市值': 335442.30000000005, '调仓目标': 85700, '调仓数量': -1000}, {'code': '518880', 'price': 3.396, '原持仓数量': 95500, '原持仓市值': 324318.0, '调仓目标': 97700, '调仓数量': 2200}, {'code': '511260', 'price': 107.43, '原持仓数量': 3000, '原持仓市值': 322290.0, '调仓目标': 3000, '调仓数量': 0}]
# 账户市值： 1106143.4059020714
# 账户可用资金： 115237.9999999999
# {'volume_long': 95500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 95500, 'volume_short': 0}
# order check success
# 下单成功 6357ea8e-532b-4544-b66d-3e60355ba077
# 全部成交 6357ea8e-532b-4544-b66d-3e60355ba077
# update trade
# {'volume_long': 86700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 86700, 'volume_short': 0}
# order check success
# 下单成功 bba01bcc-2062-4236-bef6-68451d4c84a1
# 全部成交 bba01bcc-2062-4236-bef6-68451d4c84a1
# update trade
# {'volume_long': 85700, 'volume_short': 0, 'volume_long_frozen': 1000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1600股
# 518880：调仓买入1000股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 3.945, '原持仓数量': 85700, '原持仓市值': 338086.5, '调仓目标': 84100, '调仓数量': -1600}, {'code': '518880', 'price': 3.363, '原持仓数量': 97700, '原持仓市值': 328565.1, '调仓目标': 98700, '调仓数量': 1000}, {'code': '511260', 'price': 106.651, '原持仓数量': 3000, '原持仓市值': 319953.0, '调仓目标': 3100, '调仓数量': 100}]
# 账户市值： 1107089.1533150012
# 账户可用资金： 111635.7999999999
# {'volume_long': 97700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 97700, 'volume_short': 0}
# order check success
# 下单成功 1a2bc562-256c-4e71-bc36-41d1028458ec
# 全部成交 1a2bc562-256c-4e71-bc36-41d1028458ec
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3000, 'volume_short': 0}
# order check success
# 下单成功 d51a553d-07d4-414f-a027-16d43e04d2ac
# 全部成交 d51a553d-07d4-414f-a027-16d43e04d2ac
# update trade
# {'volume_long': 85700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 85700, 'volume_short': 0}
# order check success
# 下单成功 60083390-1585-4b9b-bd80-63b847a66fb2
# 全部成交 60083390-1585-4b9b-bd80-63b847a66fb2
# update trade
# {'volume_long': 84100, 'volume_short': 0, 'volume_long_frozen': 1600, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入400股
# 518880：调仓买入1900股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 3.887, '原持仓数量': 84100, '原持仓市值': 326896.7, '调仓目标': 84500, '调仓数量': 400}, {'code': '518880', 'price': 3.265, '原持仓数量': 98700, '原持仓市值': 322255.5, '调仓目标': 100600, '调仓数量': 1900}, {'code': '511260', 'price': 107.6, '原持仓数量': 3100, '原持仓市值': 333560.0, '调仓目标': 3000, '调仓数量': -100}]
# 账户市值： 1095513.4740969238
# 账户可用资金： 103919.6999999999
# {'volume_long': 98700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 98700, 'volume_short': 0}
# order check success
# 下单成功 d5665d0f-987a-4410-8d2b-cbb80d90ce37
# 全部成交 d5665d0f-987a-4410-8d2b-cbb80d90ce37
# update trade
# {'volume_long': 84100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 84100, 'volume_short': 0}
# order check success
# 下单成功 bf8abb2b-ab3d-4be7-8c39-7ea7264c6dca
# 全部成交 bf8abb2b-ab3d-4be7-8c39-7ea7264c6dca
# update trade
# {'volume_long': 3100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3100, 'volume_short': 0}
# order check success
# 下单成功 2fff6740-3edb-4acf-b20a-733612391c38
# 全部成交 2fff6740-3edb-4acf-b20a-733612391c38
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1900股
# 518880：调仓卖出600股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 4.096, '原持仓数量': 84500, '原持仓市值': 346112.0, '调仓目标': 82600, '调仓数量': -1900}, {'code': '518880', 'price': 3.384, '原持仓数量': 100600, '原持仓市值': 340430.39999999997, '调仓目标': 100000, '调仓数量': -600}, {'code': '511260', 'price': 108.47, '原持仓数量': 3000, '原持仓市值': 325410.0, '调仓目标': 3100, '调仓数量': 100}]
# 账户市值： 1128046.8760860553
# 账户可用资金： 106921.39999999989
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3000, 'volume_short': 0}
# order check success
# 下单成功 c578f0c7-ae34-4ca4-9725-d135d4e01d84
# 全部成交 c578f0c7-ae34-4ca4-9725-d135d4e01d84
# update trade
# {'volume_long': 100600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100600, 'volume_short': 0}
# order check success
# 下单成功 dc5aa7c4-40ca-431d-ac82-e0eb70175dd1
# 全部成交 dc5aa7c4-40ca-431d-ac82-e0eb70175dd1
# update trade
# {'volume_long': 100000, 'volume_short': 0, 'volume_long_frozen': 600, 'volume_short_frozen': 0}
# {'volume_long': 84500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 84500, 'volume_short': 0}
# order check success
# 下单成功 fe1edb42-9469-4423-886b-57c877c66759
# 全部成交 fe1edb42-9469-4423-886b-57c877c66759
# update trade
# {'volume_long': 82600, 'volume_short': 0, 'volume_long_frozen': 1900, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入2000股
# 518880：调仓卖出1400股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 3.996, '原持仓数量': 82600, '原持仓市值': 330069.6, '调仓目标': 84600, '调仓数量': 2000}, {'code': '518880', 'price': 3.43, '原持仓数量': 100000, '原持仓市值': 343000.0, '调仓目标': 98600, '调仓数量': -1400}, {'code': '511260', 'price': 109.663, '原持仓数量': 3100, '原持仓市值': 339955.3, '调仓目标': 3000, '调仓数量': -100}]
# 账户市值： 1128140.9114330383
# 账户可用资金： 105887.19999999988
# {'volume_long': 82600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 82600, 'volume_short': 0}
# order check success
# 下单成功 a640a878-c9f2-4b94-a389-2dbcaa2c4398
# 全部成交 a640a878-c9f2-4b94-a389-2dbcaa2c4398
# update trade
# {'volume_long': 3100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3100, 'volume_short': 0}
# order check success
# 下单成功 53905397-ffae-4b0a-9851-54b124f88416
# 全部成交 53905397-ffae-4b0a-9851-54b124f88416
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 100000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100000, 'volume_short': 0}
# order check success
# 下单成功 7d308230-e527-49ab-ab88-61b7ae1b986b
# 全部成交 7d308230-e527-49ab-ab88-61b7ae1b986b
# update trade
# {'volume_long': 98600, 'volume_short': 0, 'volume_long_frozen': 1400, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入2900股
# 518880：调仓卖出3600股
# [{'code': '510300', 'price': 3.933, '原持仓数量': 84600, '原持仓市值': 332731.8, '调仓目标': 87500, '调仓数量': 2900}, {'code': '518880', 'price': 3.623, '原持仓数量': 98600, '原持仓市值': 357227.80000000005, '调仓目标': 95000, '调仓数量': -3600}, {'code': '511260', 'price': 111.7, '原持仓数量': 3000, '原持仓市值': 335100.0, '调仓目标': 3000, '调仓数量': 0}]
# 账户市值： 1148244.3050214604
# 账户可用资金： 113663.49999999988
# {'volume_long': 84600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 84600, 'volume_short': 0}
# order check success
# 下单成功 ab717d93-147c-4a4b-b896-c0cc155606e9
# 全部成交 ab717d93-147c-4a4b-b896-c0cc155606e9
# update trade
# {'volume_long': 98600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 98600, 'volume_short': 0}
# order check success
# 下单成功 972f73f7-6197-46a0-af9b-145a3bec0179
# 全部成交 972f73f7-6197-46a0-af9b-145a3bec0179
# update trade
# {'volume_long': 95000, 'volume_short': 0, 'volume_long_frozen': 3600, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入4500股
# 518880：调仓卖出900股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 3.669, '原持仓数量': 87500, '原持仓市值': 321037.5, '调仓目标': 92000, '调仓数量': 4500}, {'code': '518880', 'price': 3.586, '原持仓数量': 95000, '原持仓市值': 340670.0, '调仓目标': 94100, '调仓数量': -900}, {'code': '511260', 'price': 112.815, '原持仓数量': 3000, '原持仓市值': 338445.0, '调仓目标': 2900, '调仓数量': -100}]
# 账户市值： 1125231.4406366744
# 账户可用资金： 115300.59999999989
# {'volume_long': 87500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 87500, 'volume_short': 0}
# order check success
# 下单成功 81876c76-51d2-4a31-956b-ccb0bdcd9c35
# 全部成交 81876c76-51d2-4a31-956b-ccb0bdcd9c35
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3000, 'volume_short': 0}
# order check success
# 下单成功 c42bce45-f8bb-485e-91f3-5b2d7c2a622e
# 全部成交 c42bce45-f8bb-485e-91f3-5b2d7c2a622e
# update trade
# {'volume_long': 2900, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# {'volume_long': 95000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 95000, 'volume_short': 0}
# order check success
# 下单成功 094959ed-28dc-4f9e-9c7c-e75a8020323b
# 全部成交 094959ed-28dc-4f9e-9c7c-e75a8020323b
# update trade
# {'volume_long': 94100, 'volume_short': 0, 'volume_long_frozen': 900, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出2400股
# 518880：调仓卖出700股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 3.908, '原持仓数量': 92000, '原持仓市值': 359536.0, '调仓目标': 89600, '调仓数量': -2400}, {'code': '518880', 'price': 3.746, '原持仓数量': 94100, '原持仓市值': 352498.6, '调仓目标': 93400, '调仓数量': -700}, {'code': '511260', 'price': 114.501, '原持仓数量': 2900, '原持仓市值': 332052.9, '调仓目标': 3000, '调仓数量': 100}]
# 账户市值： 1167438.2152737924
# 账户可用资金： 113298.99999999988
# {'volume_long': 2900, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 2900, 'volume_short': 0}
# order check success
# 下单成功 1dfa2a14-b91f-4be5-a855-cb30e1ecb916
# 全部成交 1dfa2a14-b91f-4be5-a855-cb30e1ecb916
# update trade
# {'volume_long': 94100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 94100, 'volume_short': 0}
# order check success
# 下单成功 52a58086-4fd5-4276-8349-d8e8e1de4f8e
# 全部成交 52a58086-4fd5-4276-8349-d8e8e1de4f8e
# update trade
# {'volume_long': 93400, 'volume_short': 0, 'volume_long_frozen': 700, 'volume_short_frozen': 0}
# {'volume_long': 92000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 92000, 'volume_short': 0}
# order check success
# 下单成功 74234936-10b8-4b70-af90-e0485a2ab37b
# 全部成交 74234936-10b8-4b70-af90-e0485a2ab37b
# update trade
# {'volume_long': 89600, 'volume_short': 0, 'volume_long_frozen': 2400, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入1100股
# 518880：调仓卖出2600股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 3.866, '原持仓数量': 89600, '原持仓市值': 346393.60000000003, '调仓目标': 90700, '调仓数量': 1100}, {'code': '518880', 'price': 3.864, '原持仓数量': 93400, '原持仓市值': 360897.6, '调仓目标': 90800, '调仓数量': -2600}, {'code': '511260', 'price': 112.733, '原持仓数量': 3000, '原持仓市值': 338199.0, '调仓目标': 3100, '调仓数量': 100}]
# 账户市值： 1169505.6499791113
# 账户可用资金： 113850.29999999987
# {'volume_long': 89600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 89600, 'volume_short': 0}
# order check success
# 下单成功 6d4e448e-6498-470b-9092-8a4752cb6096
# 全部成交 6d4e448e-6498-470b-9092-8a4752cb6096
# update trade
# {'volume_long': 3000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3000, 'volume_short': 0}
# order check success
# 下单成功 5d891b87-5271-4603-bb51-31de5cf41676
# 全部成交 5d891b87-5271-4603-bb51-31de5cf41676
# update trade
# {'volume_long': 93400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 93400, 'volume_short': 0}
# order check success
# 下单成功 4bdd1355-8c2f-4342-9bf8-7461f71ed75a
# 全部成交 4bdd1355-8c2f-4342-9bf8-7461f71ed75a
# update trade
# {'volume_long': 90800, 'volume_short': 0, 'volume_long_frozen': 2600, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出4700股
# 518880：调仓买入1000股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 4.178, '原持仓数量': 90700, '原持仓市值': 378944.6, '调仓目标': 86000, '调仓数量': -4700}, {'code': '518880', 'price': 3.914, '原持仓数量': 90800, '原持仓市值': 355391.2, '调仓目标': 91800, '调仓数量': 1000}, {'code': '511260', 'price': 111.463, '原持仓数量': 3100, '原持仓市值': 345535.3, '调仓目标': 3200, '调仓数量': 100}]
# 账户市值： 1198515.0958667612
# 账户可用资金： 108370.79999999986
# {'volume_long': 90800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 90800, 'volume_short': 0}
# order check success
# 下单成功 a5883568-0097-4bf8-bbdb-0f3e3a0ccad1
# 全部成交 a5883568-0097-4bf8-bbdb-0f3e3a0ccad1
# update trade
# {'volume_long': 3100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3100, 'volume_short': 0}
# order check success
# 下单成功 c9f3a72e-5e09-4575-95f7-7f689979c8df
# 全部成交 c9f3a72e-5e09-4575-95f7-7f689979c8df
# update trade
# {'volume_long': 90700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 90700, 'volume_short': 0}
# order check success
# 下单成功 f1753792-4997-469b-85f7-ec6750464532
# 全部成交 f1753792-4997-469b-85f7-ec6750464532
# update trade
# {'volume_long': 86000, 'volume_short': 0, 'volume_long_frozen': 4700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出5700股
# 518880：调仓卖出1300股
# 511260：调仓买入200股
# [{'code': '510300', 'price': 4.75, '原持仓数量': 86000, '原持仓市值': 408500.0, '调仓目标': 80300, '调仓数量': -5700}, {'code': '518880', 'price': 4.216, '原持仓数量': 91800, '原持仓市值': 387028.80000000005, '调仓目标': 90500, '调仓数量': -1300}, {'code': '511260', 'price': 110.361, '原持仓数量': 3200, '原持仓市值': 353155.2, '调仓目标': 3400, '调仓数量': 200}]
# 账户市值： 1272627.1237047443
# 账户可用资金： 112947.09999999986
# {'volume_long': 3200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3200, 'volume_short': 0}
# order check success
# 下单成功 ce721ab0-bbdd-4886-8779-3be0a96084fb
# 全部成交 ce721ab0-bbdd-4886-8779-3be0a96084fb
# update trade
# {'volume_long': 91800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 91800, 'volume_short': 0}
# order check success
# 下单成功 33060991-867b-4b42-8071-706499852fa7
# 全部成交 33060991-867b-4b42-8071-706499852fa7
# update trade
# {'volume_long': 90500, 'volume_short': 0, 'volume_long_frozen': 1300, 'volume_short_frozen': 0}
# {'volume_long': 86000, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 86000, 'volume_short': 0}
# order check success
# 下单成功 a2828731-1761-4478-bbfb-e9af2d89aa82
# 全部成交 a2828731-1761-4478-bbfb-e9af2d89aa82
# update trade
# {'volume_long': 80300, 'volume_short': 0, 'volume_long_frozen': 5700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出2000股
# 518880：调仓买入2100股
# [{'code': '510300', 'price': 4.874, '原持仓数量': 80300, '原持仓市值': 391382.19999999995, '调仓目标': 78300, '调仓数量': -2000}, {'code': '518880', 'price': 4.123, '原持仓数量': 90500, '原持仓市值': 373131.5, '调仓目标': 92600, '调仓数量': 2100}, {'code': '511260', 'price': 109.724, '原持仓数量': 3400, '原持仓市值': 373061.60000000003, '调仓目标': 3400, '调仓数量': 0}]
# 账户市值： 1273158.8211478896
# 账户可用资金： 123430.69999999987
# {'volume_long': 90500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 90500, 'volume_short': 0}
# order check success
# 下单成功 e6c5dbbe-d7c6-4581-b0d8-36b985f676f8
# 全部成交 e6c5dbbe-d7c6-4581-b0d8-36b985f676f8
# update trade
# {'volume_long': 80300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 80300, 'volume_short': 0}
# order check success
# 下单成功 8ec0d20d-eee2-4b07-ae42-2a65c4be610b
# 全部成交 8ec0d20d-eee2-4b07-ae42-2a65c4be610b
# update trade
# {'volume_long': 78300, 'volume_short': 0, 'volume_long_frozen': 2000, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入1900股
# 518880：调仓买入1200股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 4.646, '原持仓数量': 78300, '原持仓市值': 363781.8, '调仓目标': 80200, '调仓数量': 1900}, {'code': '518880', 'price': 3.974, '原持仓数量': 92600, '原持仓市值': 367992.4, '调仓目标': 93800, '调仓数量': 1200}, {'code': '511260', 'price': 110.188, '原持仓数量': 3400, '原持仓市值': 374639.2, '调仓目标': 3300, '调仓数量': -100}]
# 账户市值： 1243115.8865531934
# 账户可用资金： 124520.39999999986
# {'volume_long': 78300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 78300, 'volume_short': 0}
# order check success
# 下单成功 0247c002-ea4d-4a16-a984-755110cce063
# 全部成交 0247c002-ea4d-4a16-a984-755110cce063
# update trade
# {'volume_long': 92600, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 92600, 'volume_short': 0}
# order check success
# 下单成功 8d983a67-38de-4cba-a48c-20e7891ad71a
# 全部成交 8d983a67-38de-4cba-a48c-20e7891ad71a
# update trade
# {'volume_long': 3400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3400, 'volume_short': 0}
# order check success
# 下单成功 fb93e46e-68c9-42b7-a6e8-ec1bcec45478
# 全部成交 fb93e46e-68c9-42b7-a6e8-ec1bcec45478
# update trade
# {'volume_long': 3300, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1700股
# 518880：调仓买入2000股
# [{'code': '510300', 'price': 4.757, '原持仓数量': 80200, '原持仓市值': 381511.39999999997, '调仓目标': 78500, '调仓数量': -1700}, {'code': '518880', 'price': 3.897, '原持仓数量': 93800, '原持仓市值': 365538.6, '调仓目标': 95800, '调仓数量': 2000}, {'code': '511260', 'price': 110.104, '原持仓数量': 3300, '原持仓市值': 363343.2, '调仓目标': 3300, '调仓数量': 0}]
# 账户市值： 1244762.9193921057
# 账户可用资金： 121942.99999999987
# {'volume_long': 93800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 93800, 'volume_short': 0}
# order check success
# 下单成功 7a11e6d7-5e3f-45a5-9f84-555312b1e764
# 全部成交 7a11e6d7-5e3f-45a5-9f84-555312b1e764
# update trade
# {'volume_long': 80200, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 80200, 'volume_short': 0}
# order check success
# 下单成功 2d392711-6231-4fad-a8b4-f32988838553
# 全部成交 2d392711-6231-4fad-a8b4-f32988838553
# update trade
# {'volume_long': 78500, 'volume_short': 0, 'volume_long_frozen': 1700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出4700股
# 518880：调仓买入6600股
# [{'code': '510300', 'price': 5.031, '原持仓数量': 78500, '原持仓市值': 394933.5, '调仓目标': 73800, '调仓数量': -4700}, {'code': '518880', 'price': 3.628, '原持仓数量': 95800, '原持仓市值': 347562.4, '调仓目标': 102400, '调仓数量': 6600}, {'code': '511260', 'price': 109.682, '原持仓数量': 3300, '原持仓市值': 361950.60000000003, '调仓目标': 3300, '调仓数量': 0}]
# 账户市值： 1239109.5063898896
# 账户可用资金： 122235.89999999986
# {'volume_long': 95800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 95800, 'volume_short': 0}
# order check success
# 下单成功 bf5e1d7c-1463-4435-90b6-5ddcd5b266a9
# 全部成交 bf5e1d7c-1463-4435-90b6-5ddcd5b266a9
# update trade
# {'volume_long': 78500, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 78500, 'volume_short': 0}
# order check success
# 下单成功 dd919992-599c-42c2-ad57-c6fb8fbfdf6e
# 全部成交 dd919992-599c-42c2-ad57-c6fb8fbfdf6e
# update trade
# {'volume_long': 73800, 'volume_short': 0, 'volume_long_frozen': 4700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出1100股
# 518880：调仓卖出2500股
# 511260：调仓买入100股
# [{'code': '510300', 'price': 5.287, '原持仓数量': 73800, '原持仓市值': 390180.6, '调仓目标': 72700, '调仓数量': -1100}, {'code': '518880', 'price': 3.85, '原持仓数量': 102400, '原持仓市值': 394240.0, '调仓目标': 99900, '调仓数量': -2500}, {'code': '511260', 'price': 110.105, '原持仓数量': 3300, '原持仓市值': 363346.5, '调仓目标': 3400, '调仓数量': 100}]
# 账户市值： 1282857.951064107
# 账户可用资金： 121936.79999999986
# {'volume_long': 3300, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3300, 'volume_short': 0}
# order check success
# 下单成功 6ddf9ed5-2f5a-47b2-9710-d1eb0657cc20
# 全部成交 6ddf9ed5-2f5a-47b2-9710-d1eb0657cc20
# update trade
# {'volume_long': 73800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 73800, 'volume_short': 0}
# order check success
# 下单成功 ae9fd34f-1935-40cd-aefc-beeeb0a19614
# 全部成交 ae9fd34f-1935-40cd-aefc-beeeb0a19614
# update trade
# {'volume_long': 72700, 'volume_short': 0, 'volume_long_frozen': 1100, 'volume_short_frozen': 0}
# {'volume_long': 102400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 102400, 'volume_short': 0}
# order check success
# 下单成功 f3969d47-37f1-4ad5-a331-06ec94966af1
# 全部成交 f3969d47-37f1-4ad5-a331-06ec94966af1
# update trade
# {'volume_long': 99900, 'volume_short': 0, 'volume_long_frozen': 2500, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出900股
# 518880：调仓买入1800股
# [{'code': '510300', 'price': 5.348, '原持仓数量': 72700, '原持仓市值': 388799.6, '调仓目标': 71800, '调仓数量': -900}, {'code': '518880', 'price': 3.778, '原持仓数量': 99900, '原持仓市值': 377422.2, '调仓目标': 101700, '调仓数量': 1800}, {'code': '511260', 'price': 110.282, '原持仓数量': 3400, '原持仓市值': 374958.8, '调仓目标': 3400, '调仓数量': 0}]
# 账户市值： 1280749.2778795464
# 账户可用资金： 126366.99999999985
# {'volume_long': 99900, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 99900, 'volume_short': 0}
# order check success
# 下单成功 99a5d0a0-f071-4b54-9c65-7acbb98a71ec
# 全部成交 99a5d0a0-f071-4b54-9c65-7acbb98a71ec
# update trade
# {'volume_long': 72700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 72700, 'volume_short': 0}
# order check success
# 下单成功 df8d737a-6f74-49ea-9198-715ffa5d0264
# 全部成交 df8d737a-6f74-49ea-9198-715ffa5d0264
# update trade
# {'volume_long': 71800, 'volume_short': 0, 'volume_long_frozen': 900, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓卖出700股
# 518880：调仓买入3100股
# [{'code': '510300', 'price': 5.329, '原持仓数量': 71800, '原持仓市值': 382622.19999999995, '调仓目标': 71100, '调仓数量': -700}, {'code': '518880', 'price': 3.613, '原持仓数量': 101700, '原持仓市值': 367442.1, '调仓目标': 104800, '调仓数量': 3100}, {'code': '511260', 'price': 110.445, '原持仓数量': 3400, '原持仓市值': 375513.0, '调仓目标': 3400, '调仓数量': 0}]
# 账户市值： 1263112.3556413064
# 账户可用资金： 124379.79999999986
# {'volume_long': 101700, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 101700, 'volume_short': 0}
# order check success
# 下单成功 31ff7b95-1d8f-4e75-b3b6-a10aaf0d5319
# 全部成交 31ff7b95-1d8f-4e75-b3b6-a10aaf0d5319
# update trade
# {'volume_long': 71800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 71800, 'volume_short': 0}
# order check success
# 下单成功 3eaf3f72-0d16-43e6-8df0-1ae257e065e0
# 全部成交 3eaf3f72-0d16-43e6-8df0-1ae257e065e0
# update trade
# {'volume_long': 71100, 'volume_short': 0, 'volume_long_frozen': 700, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# 510300：调仓买入2100股
# 518880：调仓买入900股
# 511260：调仓卖出100股
# [{'code': '510300', 'price': 5.05, '原持仓数量': 71100, '原持仓市值': 359055.0, '调仓目标': 73200, '调仓数量': 2100}, {'code': '518880', 'price': 3.495, '原持仓数量': 104800, '原持仓市值': 366276.0, '调仓目标': 105700, '调仓数量': 900}, {'code': '511260', 'price': 110.934, '原持仓数量': 3400, '原持仓市值': 377175.6, '调仓目标': 3300, '调仓数量': -100}]
# 账户市值： 1232528.1705081775
# 账户可用资金： 116909.79999999986
# {'volume_long': 71100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 71100, 'volume_short': 0}
# order check success
# 下单成功 74fa1c6b-05ea-4c8b-874a-a96dd78085b2
# 全部成交 74fa1c6b-05ea-4c8b-874a-a96dd78085b2
# update trade
# {'volume_long': 104800, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 104800, 'volume_short': 0}
# order check success
# 下单成功 dbebf836-0dd8-416b-8ae6-187976e8974a
# 全部成交 dbebf836-0dd8-416b-8ae6-187976e8974a
# update trade
# {'volume_long': 3400, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 3400, 'volume_short': 0}
# order check success
# 下单成功 6b08c4a5-f9fc-4e23-9091-946b02ac33ac
# 全部成交 6b08c4a5-f9fc-4e23-9091-946b02ac33ac
# update trade
# {'volume_long': 3300, 'volume_short': 0, 'volume_long_frozen': 100, 'volume_short_frozen': 0}
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle
# settle

# %%
import QIFIAccount

acc = QIFIAccount.QAQIFIAccount.QIFI_Account(username='test37', password='test37', model="BACKTEST")

acc.initial()

for i in range(10,29):
    date = '2021-01-%s'%i
    price = 20+i/10
    acc.on_price_change('000001', price, date+' 09:35:00')

    # 奇数开仓，偶数平仓
    if i %2 ==0:
        order = acc.send_order('000001', 100, price, QIFIAccount.ORDER_DIRECTION.BUY, datetime=date+' 09:58:00')
        acc.make_deal(order)
    else:
        order = acc.send_order('000001', 100, price, QIFIAccount.ORDER_DIRECTION.SELL, datetime=date+' 10:58:00')
        acc.make_deal(order)

    pos = acc.get_position('000001')
    # print(pos.realtime_message)
    acc.settle()
# Out:
# Create new Account
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 fc0c1a51-0127-4ce9-a1b3-7dda48cba296
# 全部成交 fc0c1a51-0127-4ce9-a1b3-7dda48cba296
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 ffdc7174-ff6b-44e5-bf4c-9ca664521186
# 全部成交 ffdc7174-ff6b-44e5-bf4c-9ca664521186
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 4f744976-2eae-458d-86c5-1b21ce5ef8fd
# 全部成交 4f744976-2eae-458d-86c5-1b21ce5ef8fd
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 36905829-cdb0-46d1-9f6d-053701e01eb4
# 全部成交 36905829-cdb0-46d1-9f6d-053701e01eb4
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 3e108a5b-77d0-4f61-9f1f-e66317553477
# 全部成交 3e108a5b-77d0-4f61-9f1f-e66317553477
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 6bad42d3-05aa-4a4d-8ea7-36fe8ed5dc25
# 全部成交 6bad42d3-05aa-4a4d-8ea7-36fe8ed5dc25
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 fbdd429d-fbcb-4c82-ad07-d3bc9bc26844
# 全部成交 fbdd429d-fbcb-4c82-ad07-d3bc9bc26844
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 2975e2a7-3494-4b2b-8737-cafc282f9023
# 全部成交 2975e2a7-3494-4b2b-8737-cafc282f9023
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 5800a789-c774-4a9d-a98d-03f3edeaa00f
# 全部成交 5800a789-c774-4a9d-a98d-03f3edeaa00f
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 73148965-7515-48ef-8928-2c173b2c1983
# 全部成交 73148965-7515-48ef-8928-2c173b2c1983
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 14383793-9f30-41bc-9462-183efecd3613
# 全部成交 14383793-9f30-41bc-9462-183efecd3613
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 fb214e4e-3f91-4d66-9986-0e9641f1a0d2
# 全部成交 fb214e4e-3f91-4d66-9986-0e9641f1a0d2
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 81d1a5ea-d395-4ca6-9dda-cee7f6ccf27c
# 全部成交 81d1a5ea-d395-4ca6-9dda-cee7f6ccf27c
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 c315af31-9700-4e9e-9520-7be9477867b7
# 全部成交 c315af31-9700-4e9e-9520-7be9477867b7
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 96d0aafa-5ccb-43c9-93dc-5d4f6a72f5f8
# 全部成交 96d0aafa-5ccb-43c9-93dc-5d4f6a72f5f8
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 4502e591-a963-4170-b17b-b2c0825faffe
# 全部成交 4502e591-a963-4170-b17b-b2c0825faffe
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 176cd58a-7a91-408b-9246-fa28610ec814
# 全部成交 176cd58a-7a91-408b-9246-fa28610ec814
# update trade
# settle
# {'volume_long': 100, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 100, 'volume_short': 0}
# order check success
# 下单成功 8a82cd81-d2a5-43ff-91ee-1ffc0369db7b
# 全部成交 8a82cd81-d2a5-43ff-91ee-1ffc0369db7b
# update trade
# settle
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# order check success
# 下单成功 ea158f68-bd78-4f49-a282-ff0f0dde0f67
# 全部成交 ea158f68-bd78-4f49-a282-ff0f0dde0f67
# update trade
# settle
